# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plt(x,y,'g+')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 7
#       4 x = [1,2,3,4,5,6,7]
#       5 y = [50,51,52,48,47,49,46]
# ----> 7 plt.plt(x,y,'g+')
#       8 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'plt'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

plt.plot(x,y,'g+', markersize=18)
plt.show()

# %%
plt.plot(x,y, 'r--*')
plt.show()

# %%
plt.plot(x,y, 'r--*', markersize=5, alpha= 0.8)
plt.show()
