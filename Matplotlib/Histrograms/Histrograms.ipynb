# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 110]
blood_pressure_men = [85,90,95,110,120,135,150,165,170,125,130,140,112,92,98]
blood_pressure_women = [80,79,75,110,120,145,150,125,105,125,114,140,112,92,98]
plt.xlabel('Blood Sugar Level')
plt.ylabel('Frequency')
plt.title('Blood Sugar Analysis')

plt.hist([blood_sugar_men, blood_sugar_women,blood_pressure_men,blood_pressure_women], bins=[80,100,125,150], rwidth=0.95, color=['green','yellow','orange','red'],label=['men', 'women'])
plt.legend(shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 110]
plt.xlabel('Blood Sugar Level')
plt.ylabel('Frequency')
plt.title('Blood Sugar Analysis')

plt.hist([blood_sugar_men, blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['green','orange'],label=['men', 'women'], orientation="horizontal")
plt.legend(shadow=True)
plt.show()
