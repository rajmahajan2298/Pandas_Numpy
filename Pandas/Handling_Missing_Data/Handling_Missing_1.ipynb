# %%
import pandas as pd

df = pd.read_csv("C:/Users/hp/Pandas//Handling_Missing_Data/weather_data.csv")
df
# Out:
#          days  temperature  windspeed     event
# 0  01-01-2017           32          6      Rain
# 1  01-02-2017       -99999          7     Sunny
# 2  01-03-2017           28     -99999      Snow
# 3  01-04-2017       -99999          9  no event
# 4  01-05-2017           28     -99999      Rain
# 5  01-06-2017           31          2     Sunny
# 6  01-06-2017           34     -88888  no event

# %%
df.replace(-99999, 0)
# Out:
#          days  temperature  windspeed     event
# 0  01-01-2017           32          6      Rain
# 1  01-02-2017            0          7     Sunny
# 2  01-03-2017           28          0      Snow
# 3  01-04-2017            0          9  no event
# 4  01-05-2017           28          0      Rain
# 5  01-06-2017           31          2     Sunny
# 6  01-06-2017           34     -88888  no event

# %%
import numpy as np

df.replace(-99999,np.nan)
# Out:
#          days  temperature  windspeed     event
# 0  01-01-2017         32.0        6.0      Rain
# 1  01-02-2017          NaN        7.0     Sunny
# 2  01-03-2017         28.0        NaN      Snow
# 3  01-04-2017          NaN        9.0  no event
# 4  01-05-2017         28.0        NaN      Rain
# 5  01-06-2017         31.0        2.0     Sunny
# 6  01-06-2017         34.0   -88888.0  no event

# %%
df.replace([-99999,-88888], np.nan)
# Out:
#          days  temperature  windspeed     event
# 0  01-01-2017         32.0        6.0      Rain
# 1  01-02-2017          NaN        7.0     Sunny
# 2  01-03-2017         28.0        NaN      Snow
# 3  01-04-2017          NaN        9.0  no event
# 4  01-05-2017         28.0        NaN      Rain
# 5  01-06-2017         31.0        2.0     Sunny
# 6  01-06-2017         34.0        NaN  no event

# %%
df
# Out:
#          days  temperature  windspeed     event
# 0  01-01-2017           32          6      Rain
# 1  01-02-2017       -99999          7     Sunny
# 2  01-03-2017           28     -99999      Snow
# 3  01-04-2017       -99999          9  no event
# 4  01-05-2017           28     -99999      Rain
# 5  01-06-2017           31          2     Sunny
# 6  01-06-2017           34     -88888  no event

# %%
df.replace({
    'temperature': -99999,
    'windspeed': [-99999,-88888],
    'event': 'no event'
}, np.nan)
# Out:
#          days  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        9.0    NaN
# 4  01-05-2017         28.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        NaN    NaN

# %%
df.replace({
    -99999: np.nan,
    -88888: np.nan,
    'no event': 'Sunny'
})
# Out:
#          days  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        9.0  Sunny
# 4  01-05-2017         28.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        NaN  Sunny

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor','average','good', 'exceptional'],[1,2,3,4])
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica
